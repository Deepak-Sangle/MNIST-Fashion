# %% [markdown]
# # Fashion-MNIST Dataset
# A quick look at the Fashion-MNIST dataset used in this coursework. Note: Please do not submit this file as part of your assignment.
#
# From the authors: "`Fashion-MNIST` is a dataset of [Zalando](https://jobs.zalando.com/tech/)'s article images—consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes."
#
# Each image is a single clothing item from one of these 10 categories:
#
# | Label | Class |
# |-------|-------|
# | 0 | T-shirt/top |
# | 1 | Trouser |
# | 2 | Pullover |
# | 3 | Dress |
# | 4 | Coat |
# | 5 | Sandal |
# | 6 | Shirt |
# | 7 | Sneaker |
# | 8 | Bag |
# | 9 | Ankle boot |

# %% [markdown]
# ## Load the dataset

# %%
import matplotlib.pyplot as plt

from submission.fashion_training import load_training_data
# Load dataset
dataset = load_training_data()

# Class names
classes = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
           'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

print(f"Dataset size: {len(dataset)} images")
print(f"Image shape: 28x28 grayscale")
print(f"Classes: {len(classes)}")
# Out:
# Loading Fashion-MNIST dataset...
# Dataset size: 60000 images
# Image shape: 28x28 grayscale
# Classes: 10

# %% [markdown]
# ## Visualise Sample Images

# %%
# Display sample images
fig, axes = plt.subplots(2, 5, figsize=(12, 5))
fig.suptitle('Fashion-MNIST Sample Images', fontsize=16)

for i, ax in enumerate(axes.flat):
    image, label = dataset[i]
    ax.imshow(image, cmap='gray')
    ax.set_title(classes[label])
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       5 for i, ax in enumerate(axes.flat):
#       6     image, label = dataset[i]
# ----> 7     ax.imshow(image, cmap='gray')
#       8     ax.set_title(classes[label])
#       9     ax.axis('off')
#
# File /opt/miniconda3/envs/comp60561/lib/python3.10/site-packages/matplotlib/__init__.py:1524, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1521 @functools.wraps(func)
#    1522 def inner(ax, *args, data=None, **kwargs):
#    1523     if data is None:
# -> 1524         return func(
#    1525             ax,
#    1526             *map(cbook.sanitize_sequence, args),
#    1527             **{k: cbook.sanitize_sequence(v) for k, v in kwargs.items()})
#    1529     bound = new_sig.bind(ax, *args, **kwargs)
#    1530     auto_label = (bound.arguments.get(label_namer)
# ...

# %%
# Show one image in detail
image, label = dataset[0]

plt.figure(figsize=(4, 4))
plt.imshow(image, cmap='gray')
plt.title(f'Label: {label} ({classes[label]})')
plt.axis('off')
plt.show()

print(f"Image size: {image.size}")
print(f"Label: {label}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       2 image, label = dataset[0]
#       4 plt.figure(figsize=(4, 4))
# ----> 5 plt.imshow(image, cmap='gray')
#       6 plt.title(f'Label: {label} ({classes[label]})')
#       7 plt.axis('off')
#
# File /opt/miniconda3/envs/comp60561/lib/python3.10/site-packages/matplotlib/pyplot.py:3601, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, colorizer, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    3579 @_copy_docstring_and_deprecators(Axes.imshow)
#    3580 def imshow(
#    3581     X: ArrayLike | PIL.Image.Image,
#    (...)
#    3599     **kwargs,
#    3600 ) -> AxesImage:
# -> 3601     __ret = gca().imshow(
#    3602         X,
#    3603         cmap=cmap,
#    3604         norm=norm,
#    3605         aspect=aspect,
# ...

# %% [markdown]
# ## What next?
# You may wish to examine:
# - class distribution: is this a balanced dataset?
# - data shape: how will this be passed into for your model?
# - pixel intensities: create a histogram (hint: would normalisation be useful here?)
#
# Once you have explored the dataset, you can move on to defining and training your model:
# - Define your model architecture in `submission/fashion_model.py`
# - Configure training in `submission/fashion_training.py`
#
#
# What model choices are appropriate considering the dataset characteristics? How can you evaluate your model's performance without data leakage or overfitting?
